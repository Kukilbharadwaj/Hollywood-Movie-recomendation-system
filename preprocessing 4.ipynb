# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                  Title  \
# 0     JANUARY          3             The Grudge
# 1     JANUARY         10             Underwater
# 2     JANUARY         10            Like a Boss
# 3     JANUARY         10          Three Christs
# 4     JANUARY         10      Inherit the Viper
# ..        ...        ...                    ...
# 267  DECEMBER         25       We Can Be Heroes
# 268  DECEMBER         25      News of the World
# 269  DECEMBER         25  One Night in Miami...
# 270  DECEMBER         25  Promising Young Woman
# 271  DECEMBER         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                                   Paramount Pictures
# 3                                            IFC Films
# 4       Barry Films / Tycor International Film Company
# ..                                                 ...
# 267                     Netflix / Troublemaker Studios
# 268        Universal Pictures / Perfect World Pictures
# 269                                     Amazon Studios
# 270          Focus Features / FilmNation Entertainment
# 271                             Netflix / Bron Studios
#
#                                          Cast and crew   Ref.
# 0    Nicolas Pesce (director/screenplay); Andrea Ri...    [2]
# 1    William Eubank (director); Brian Duffield, Ada...    [3]
# 2    Miguel Arteta (director); Sam Pitman, Adam Col...    [4]
# 3    Jon Avnet (director/screenplay); Eric Nazarian...    NaN
# 4    Anthony Jerjen (director); Andrew Crabtree (sc...    [5]
# ..                                                 ...    ...
# 267  Robert Rodriguez (director/screenplay); Priyan...  [239]
# 268  Paul Greengrass (director/screenplay); Luke Da...  [240]
# 269  Regina King (director); Kemp Powers (screenpla...  [241]
# 270  Emerald Fennell (director/screenplay); Carey M...  [242]
# 271  Kornél Mundruczó (director); Kata Wéber (scree...  [243]
#
# [272 rows x 6 columns]

# %%
df_2020 = df[['Title','Cast and crew']]

# %%
df_2020
# Out:
#                      Title                                      Cast and crew
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 267       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 268      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 269  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 270  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 271      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# [272 rows x 2 columns]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '1706f19c7062d21150c1c7620a5dce33'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/550?api_key=1706f19c7062d21150c1c7620a5dce33'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))
# Out:
# <ipython-input-14-fdc91464740e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 267       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 268      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 269  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 270  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 271      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#     genres
# 0    Drama
# 1    Drama
# 2    Drama
# 3    Drama
# 4    Drama
# ..     ...
# 267  Drama
# 268  Drama
# 269  Drama
# 270  Drama
# 271  Drama
#
# [272 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# <ipython-input-18-d8d203d73720>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))
# <ipython-input-18-d8d203d73720>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 267       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 268      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 269  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 270  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 271      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#     genres           actor_1_name     director_name       actor_2_name  \
# 0    Drama     Andrea Riseborough     Nicolas Pesce      Demián Bichir
# 1    Drama        Kristen Stewart    William Eubank     Vincent Cassel
# 2    Drama        Tiffany Haddish     Miguel Arteta         Rose Byrne
# 3    Drama           Richard Gere         Jon Avnet     Peter Dinklage
# 4    Drama          Josh Hartnett    Anthony Jerjen  Margarita Levieva
# ..     ...                    ...               ...                ...
# 267  Drama  Priyanka Chopra Jonas  Robert Rodriguez       Pedro Pascal
# 268  Drama              Tom Hanks   Paul Greengrass      Helena Zengel
# 269  Drama      Kingsley Ben-Adir       Regina King          Eli Goree
# 270  Drama         Carey Mulligan   Emerald Fennell         Bo Burnham
# 271  Drama          Vanessa Kirby  Kornél Mundruczó       Shia LaBeouf
#
#         actor_3_name
# 0           John Cho
# 1    Jessica Henwick
# 2        Salma Hayek
# 3     Walton Goggins
# 4     Chandler Riggs
# ..               ...
# 267    YaYa Gosselin
# 268              NaN
# 269      Aldis Hodge
# 270      Alison Brie
# 271     Molly Parker
#
# [272 rows x 7 columns]

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 267  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 268   Paul Greengrass              Tom Hanks      Helena Zengel
# 269       Regina King      Kingsley Ben-Adir          Eli Goree
# 270   Emerald Fennell         Carey Mulligan         Bo Burnham
# 271  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name genres            movie_title
# 0           John Cho  Drama             The Grudge
# 1    Jessica Henwick  Drama             Underwater
# 2        Salma Hayek  Drama            Like a Boss
# 3     Walton Goggins  Drama          Three Christs
# 4     Chandler Riggs  Drama      Inherit the Viper
# ..               ...    ...                    ...
# 267    YaYa Gosselin  Drama       We Can Be Heroes
# 268              NaN  Drama      News of the World
# 269      Aldis Hodge  Drama  One Night in Miami...
# 270      Alison Brie  Drama  Promising Young Woman
# 271     Molly Parker  Drama      Pieces of a Woman
#
# [272 rows x 6 columns]

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']

# %%
new_df20.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      5
# actor_3_name     28
# genres            0
# movie_title       1
# comb             28
# dtype: int64

# %%
new_df20 = new_df20.dropna(how='any')

# %%
new_df20.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()
# Out:
# <ipython-input-31-83e83e91073b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df20['movie_title'] = new_df20['movie_title'].str.lower()

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 266       Pete Docter             Jamie Foxx           Tina Fey
# 267  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 269       Regina King      Kingsley Ben-Adir          Eli Goree
# 270   Emerald Fennell         Carey Mulligan         Bo Burnham
# 271  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name genres            movie_title  \
# 0           John Cho  Drama             the grudge
# 1    Jessica Henwick  Drama             underwater
# 2        Salma Hayek  Drama            like a boss
# 3     Walton Goggins  Drama          three christs
# 4     Chandler Riggs  Drama      inherit the viper
# ..               ...    ...                    ...
# 266    Graham Norton  Drama                   soul
# 267    YaYa Gosselin  Drama       we can be heroes
# 269      Aldis Hodge  Drama  one night in miami...
# 270      Alison Brie  Drama  promising young woman
# 271     Molly Parker  Drama      pieces of a woman
#
#                                                   comb
# 0    Andrea Riseborough Demián Bichir John Cho Nico...
# 1    Kristen Stewart Vincent Cassel Jessica Henwick...
# 2    Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3    Richard Gere Peter Dinklage Walton Goggins Jon...
# 4    Josh Hartnett Margarita Levieva Chandler Riggs...
# ..                                                 ...
# 266  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 267  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 269  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 270  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 271  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [244 rows x 7 columns]

# %%
old_df = pd.read_csv('final_data.csv')

# %%
old_df
# Out:
#       Unnamed: 0  Unnamed: 0.1          director_name          actor_1_name  \
# 0              0           0.0          James Cameron           CCH Pounder
# 1              1           1.0         Gore Verbinski           Johnny Depp
# 2              2           2.0             Sam Mendes       Christoph Waltz
# 3              3           3.0      Christopher Nolan             Tom Hardy
# 4              4           4.0            Doug Walker           Doug Walker
# ...          ...           ...                    ...                   ...
# 5359        5359         524.0            Jim Strouse      Jessica Williams
# 5360        5360         525.0            Farhad Mann         Adelaide Kane
# 5361        5361         526.0       Hannaleena Hauru        Inka Haapamäki
# 5362        5362         527.0  Jonathan A. Rosenbaum  Lou Diamond Phillips
# 5363        5363         529.0           Ravi Udyawar        Sridevi Kapoor
#
#                 actor_2_name          actor_3_name  \
# 0           Joel David Moore             Wes Studi
# 1              Orlando Bloom        Jack Davenport
# 2               Rory Kinnear      Stephanie Sigman
# 3             Christian Bale  Joseph Gordon-Levitt
# 4                 Rob Walker               unknown
# ...                      ...                   ...
# 5359            Chris O'Dowd       Keith Stanfield
# 5360  Benjamin Hollingsworth     Jean Louisa Kelly
# 5361           Rosa Honkonen        Tiitus Rantala
# 5362           Wallace Shawn           Gina Holden
# 5363               Sajal Ali        Akshaye Khanna
#
#                                genres  \
# 0     Action Adventure Fantasy Sci-Fi
# 1            Action Adventure Fantasy
# 2           Action Adventure Thriller
# 3                     Action Thriller
# 4                         Documentary
# ...                               ...
# 5359                   Romance Comedy
# 5360                          Romance
# 5361                   Romance Comedy
# 5362       Crime Comedy Action Family
# 5363             Crime Drama Thriller
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5359                       the incredible jessica james
# 5360                                  can't buy my love
# 5361                   thick lashes of lauri mäntyvaara
# 5362                        cop and a half: new recruit
# 5363                                                mom
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5359  Jessica Williams Chris O'Dowd Keith Stanfield ...
# 5360  Adelaide Kane Benjamin Hollingsworth Jean Loui...
# 5361  Inka Haapamäki Rosa Honkonen Tiitus Rantala Ha...
# 5362  Lou Diamond Phillips Wallace Shawn Gina Holden...
# 5363  Sridevi Kapoor Sajal Ali Akshaye Khanna Ravi U...
#
# [5364 rows x 9 columns]

# %%
final_df = old_df.append(new_df20,ignore_index=True)

# %%
final_df
# Out:
#       Unnamed: 0  Unnamed: 0.1      director_name           actor_1_name  \
# 0            0.0           0.0      James Cameron            CCH Pounder
# 1            1.0           1.0     Gore Verbinski            Johnny Depp
# 2            2.0           2.0         Sam Mendes        Christoph Waltz
# 3            3.0           3.0  Christopher Nolan              Tom Hardy
# 4            4.0           4.0        Doug Walker            Doug Walker
# ...          ...           ...                ...                    ...
# 5603         NaN           NaN        Pete Docter             Jamie Foxx
# 5604         NaN           NaN   Robert Rodriguez  Priyanka Chopra Jonas
# 5605         NaN           NaN        Regina King      Kingsley Ben-Adir
# 5606         NaN           NaN    Emerald Fennell         Carey Mulligan
# 5607         NaN           NaN   Kornél Mundruczó          Vanessa Kirby
#
#           actor_2_name          actor_3_name                           genres  \
# 0     Joel David Moore             Wes Studi  Action Adventure Fantasy Sci-Fi
# 1        Orlando Bloom        Jack Davenport         Action Adventure Fantasy
# 2         Rory Kinnear      Stephanie Sigman        Action Adventure Thriller
# 3       Christian Bale  Joseph Gordon-Levitt                  Action Thriller
# 4           Rob Walker               unknown                      Documentary
# ...                ...                   ...                              ...
# 5603          Tina Fey         Graham Norton                            Drama
# 5604      Pedro Pascal         YaYa Gosselin                            Drama
# 5605         Eli Goree           Aldis Hodge                            Drama
# 5606        Bo Burnham           Alison Brie                            Drama
# 5607      Shia LaBeouf          Molly Parker                            Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5603                                               soul
# 5604                                   we can be heroes
# 5605                              one night in miami...
# 5606                              promising young woman
# 5607                                  pieces of a woman
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5603  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 5604  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 5605  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 5606  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 5607  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [5608 rows x 9 columns]

# %%
final_df= final_df.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title','comb']]

# %%
final_df
# Out:
#           director_name           actor_1_name      actor_2_name  \
# 0         James Cameron            CCH Pounder  Joel David Moore
# 1        Gore Verbinski            Johnny Depp     Orlando Bloom
# 2            Sam Mendes        Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan              Tom Hardy    Christian Bale
# 4           Doug Walker            Doug Walker        Rob Walker
# ...                 ...                    ...               ...
# 5603        Pete Docter             Jamie Foxx          Tina Fey
# 5604   Robert Rodriguez  Priyanka Chopra Jonas      Pedro Pascal
# 5605        Regina King      Kingsley Ben-Adir         Eli Goree
# 5606    Emerald Fennell         Carey Mulligan        Bo Burnham
# 5607   Kornél Mundruczó          Vanessa Kirby      Shia LaBeouf
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 5603         Graham Norton                            Drama
# 5604         YaYa Gosselin                            Drama
# 5605           Aldis Hodge                            Drama
# 5606           Alison Brie                            Drama
# 5607          Molly Parker                            Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5603                                               soul
# 5604                                   we can be heroes
# 5605                              one night in miami...
# 5606                              promising young woman
# 5607                                  pieces of a woman
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5603  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 5604  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 5605  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 5606  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 5607  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [5608 rows x 7 columns]

# %%
final_df.to_csv('main_data.csv',index=False)
